# %% [markdown]
# <font size="12">Project 2:Getting Data and Analyze  </font>

# %% [markdown]
# <li><font size="4">Class:DAV 5400 Analytics Programming</font>
# <li><font size="4">Director:Stefanie Molin </font>
# <li><font size="4">Author:Zhengnan Li </font>
# <li><font size="4">Student Id: 800763534 </font>

# %% [markdown]
# should install pyproject.toml before start.
#
# $ pip3 install pyproject.toml

# %% [markdown]
# <font size="6">Part 1: XML Parsing </font>

# %% [markdown]
# <font size="5">1.1 Data introduction </font>

# %% [markdown]
# The data I choose is about the normal weight, overweight, and obesity among adults aged 20 and over by selected population characteristics:United States.
#
# This is my data:Normal weight, overweight, and obesity among adults aged 20 and over, by selected characteristics: United States
# https://catalog.data.gov/dataset/normal-weight-overweight-and-obesity-among-adults-aged-20-and-over-by-selected-characteris-8e2b1)

# %% [markdown]
# <font size="5">1.2 Initialization and checking the robots.txt.</font>

# %% [markdown]
# Before start, we need to make a initialization of class and observe what the xml includes.

# %%
from src.project_source.xml_parsing import XMLname
xmlname_instance = XMLname(base_url='https://data.cdc.gov')
# Call the method on the instance
result_df = xmlname_instance.get_sitemap_data()
# Print or use the result DataFrame as needed
print(result_df)
# Out:
#                                         Sitemap_URLs
# 0  https://s3.amazonaws.com/sa-socrata-sitemaps-u...

# %% [markdown]
# <font size="5">1.3 Parsing XML and converting to dataframe</font>

# %% [markdown]
# We can see that there is another sitemap in this url. We need to parse this sitemap and analyze its content as follows.

# %%
from src.project_source.xml_parsing import XML
part_1 = XML()
part_1.parse_xml()
# Out:
# https://s3.amazonaws.com/sa-socrata-sitemaps-us-east-1-fedramp-prod/sitemaps/sitemap-datasets-data.cdc.gov0.xml
#        {http://www.sitemaps.org/schemas/sitemap/0.9}loc  \
# 0     https://data.cdc.gov/browse?category%3DNutriti...
# 1     https://data.cdc.gov/browse?category%3DSurvey+...
# 2         https://data.cdc.gov/browse?category%3DPolicy
# 3     https://data.cdc.gov/browse?category%3DAlcohol...
# 4          https://data.cdc.gov/browse?category%3DNNDSS
# ...                                                 ...
# 1613  https://data.cdc.gov/dataset/API-update-Refres...
# 1614  https://data.cdc.gov/Public-Health-Surveillanc...
# 1615  https://data.cdc.gov/dataset/edav-demo-dataset...
# 1616  https://data.cdc.gov/dataset/JMK_DHDS_POC/bst4...
# 1617  https://data.cdc.gov/NCHS/National-Ambulatory-...
#
#      {http://www.sitemaps.org/schemas/sitemap/0.9}lastmod
# 0                      2023-07-14T18:33:16.000000+00:00
# 1                      2023-07-14T18:33:16.000000+00:00
# ...

# %% [markdown]
# <font size="5">1.4 Description of usage of data</font>

# %% [markdown]
# This is a data the normal weight, overweight, and obesity among adults aged 20 and over by selected population characteristics. We can analyze different range of ages and their weight and BMI to figur out if there are some relationships between ages and weight. And we can combine the eating habits research and exercise situation to analyze health situation in US and what we should suggest to people.

# %% [markdown]
# <font size="6">Part 2: Using an API </font>

# %% [markdown]
# <font size="5">2.1 Data introduction </font>

# %% [markdown]
#  The data I find is the information on hourly NYC Ferry boardings by date, route, direction, ferry landing, and day of week. 'Boardings' are the total number of people who boarded a vessel during the time period in question. This data forms the basis of internal NYC Ferry ridership tasks to guide service planning.
#
# This is my data link:
#
# NYC Ferry Ridership
# https://data.cityofnewyork.us/resource/t5n6-gx8c.json

# %% [markdown]
# <font size="5">2.2 Initialization.</font>

# %% [markdown]
# Before start, we need to make a initialization of class.

# %%
from src.project_source.api import API
part_2 = API()

# %% [markdown]
# <font size="5">2.3 Using API and Converting to dataframe </font>

# %%
df = part_2.api_step_1()
df
# Out:
#                         date hour route direction                     stop  \
# 0    2021-07-01T00:00:00.000    5    RW        NB                 Rockaway
# 1    2021-07-01T00:00:00.000    5    RW        NB          Sunset Park/BAT
# 2    2021-07-01T00:00:00.000    5    SV        SB         East 34th Street
# 3    2021-07-01T00:00:00.000    5    SV        SB             East 90th St
# 4    2021-07-01T00:00:00.000    5    SV        SB                Soundview
# ..                       ...  ...   ...       ...                      ...
# 995  2021-07-02T00:00:00.000    8    SB        NB          Wall St/Pier 11
# 996  2021-07-02T00:00:00.000    8    SB        SB  Atlantic Ave/BBP Pier 6
# 997  2021-07-02T00:00:00.000    8    SB        SB                Bay Ridge
# 998  2021-07-02T00:00:00.000    8    SB        SB            Corlears Hook
# 999  2021-07-02T00:00:00.000    8    SB        SB         Dumbo/BBP Pier 1
#
#     boardings  typeday
# 0          20  Weekday
# ...

# %% [markdown]
# <font size="5">2.4 Description of usage of data </font>

# %% [markdown]
# With a dataset containing information on hourly NYC Ferry boardings. We can analyze the overall trend in NYC Ferry boardings over time. Look for patterns, seasonality, and any long-term trends. This can help in understanding the general demand for ferry services.
#
# Apart from this, we can also identify peak boarding hours and off-peak hours. Understanding when the ferry services experience the highest and lowest demand can aid in optimizing service schedules

# %% [markdown]
# <font size="6">Part 3: Web Scraping </font>

# %% [markdown]
# <font size="5">3.1 Data introduction </font>

# %% [markdown]
# The data is about the Second-hand car of jajuar. We can analyse its price and compare them.
#
# This is my data link:https://www.cars.com/shopping/jaguar/

# %% [markdown]
# <font size="5">3.2 Initialization and checking the robots.txt.</font>

# %% [markdown]
# Before start, we need to make a initialization of class.And check the robots.txt in url box in page to ensure that the content in the web can be scraped.

# %%
from src.project_source.web_scraping import Web
part_3 = Web()
part_3

# %%
# Call the scrap_web method to fetch and parse the web page
part_3.scrap_web()
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-spark" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Used Jaguar Cars for Sale Near Me | Cars.com</title>
# <meta content="Shop Jaguar vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 158 Jaguar models nationwide." name="description"/>
# <link href="https://www.cars.com/shopping/jaguar/" rel="canonical"/>
# <link href="https://www.cars.com/shopping/jaguar/?page=2" rel="next"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Used Jaguar Cars for Sale Near Me | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/jaguar/" property="og:url"/>
# ...

# %%
# Call the convert_df method to extract the page content
result = part_3.convert_df()

# Print or use the result as needed
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lizhengnan/Desktop/Project-2/Project-2-Getting-Data-and-Analyze/project2_Getting_Data.ipynb 单元格 32 line 2
#       <a href='vscode-notebook-cell:/Users/lizhengnan/Desktop/Project-2/Project-2-Getting-Data-and-Analyze/project2_Getting_Data.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> # Call the convert_df method to extract the page content
# ----> <a href='vscode-notebook-cell:/Users/lizhengnan/Desktop/Project-2/Project-2-Getting-Data-and-Analyze/project2_Getting_Data.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> result = part_3.convert_df()
#       <a href='vscode-notebook-cell:/Users/lizhengnan/Desktop/Project-2/Project-2-Getting-Data-and-Analyze/project2_Getting_Data.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a> # Print or use the result as needed
# ...

# %% [markdown]
# After initialization, we need to do is checking the robots.txt in url box in web.

# %% [markdown]
# <font size="5">3.3 Description of usage of data</font>

# %% [markdown]
# Using libraries like Matplotlib or Seaborn to create visualizations. For example, we can create histograms, box plots, scatter plots, or bar charts to visually represent the distribution and relationships between different variables.
# 1. We can use the data to calculate basic descriptive statistics such as mean, median, mode, standard deviation, etc., for tuition fees, ranks, or any other numerical variables.
# 2. Explore the distribution of ranks and tuition fees.
# 3. Group the data by city and analyze the average rank or tuition fee for each city.

# %% [markdown]
# <font size="6">Part 4: Analyze dataset </font>

# %% [markdown]
# I choose to use the dataset from Part 2: NYC Ferry Ridership

# %% [markdown]
# <font size="5">4.1 Data introduction </font>

# %% [markdown]
# Please find this part in 2.1

# %% [markdown]
# <font size="5">4.2 Exploratory Data Analysis </font>

# %% [markdown]
# Q1: Which route is the most busy route according to its total boarding number.

# %%
from src.project_source.EDA import Ferry_EDA
part_4 = Ferry_EDA()

# %%
part_4.route_analysis()

# %% [markdown]
# We can see that the ER route is the most busy route.

# %% [markdown]
# Q2: When is the most busy time in a day?

# %%
part_4.hour_analysis()

# %% [markdown]
# We can see that 17:00 is the most busy time in a day.

# %% [markdown]
# Q3: What is The general direction (northbound or southbound) a route is going?

# %%
part_4.directional_analysis()

# %% [markdown]
# Which stop has the most people where riders boarded.

# %%
part_4.stop_specific_analysis()

# %% [markdown]
# <font size="5">4.2 Exploratory Data Analysis </font>

# %% [markdown]
# From the Exploratory Data Analysis above. We can get a conclusion that the Route ER is the most busy route especially at 17:00. And ER route land most at Wall St/Pier 11. We need to find some data about how long people need to wait at the stop. If too long. We can consider to add more route especially south direction.

# %% [markdown]
# <font size="6">References </font>

# %% [markdown]
# <li>1.https://www.cdc.gov/nchs/data/hus/hus19-appendix-508.pdf
# <li>2.https://medium.com/@annmohankunnath/an-introduction-to-web-scraping-with-python-bc9563fe8860
# <li>3.https://www.ferry.nyc/routes-and-schedules/
